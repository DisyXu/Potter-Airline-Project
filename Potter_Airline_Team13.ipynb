# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np

# %%
flights = pd.read_csv("potter_airlines_flights.csv")

# %%
flights.head()
# Out:
#   flight_id origin destination departure_date departure_time  base_fare_cad  \
# 0    PA0001    YUL         YYZ     2026-09-24          18:35         110.46
# 1    PA0002    YWG         YYZ     2026-10-10          16:10         146.71
# 2    PA0003    YHZ         YUL     2026-09-24          16:10         132.83
# 3    PA0004    YYC         YEG     2027-02-15          10:45          93.53
# 4    PA0005    YYZ         YHZ     2026-10-27          08:15         165.21
#
#    capacity  seats_remaining  demand_score demand_level   season  is_weekend
# 0       180                0          1.32         high  regular       False
# 1       220                1          1.05       medium  regular        True
# 2       150              150          0.81          low  regular       False
# 3       120               84          0.88          low  regular       False
# 4       180               46          1.08       medium  regular       False

# %%
flights.shape
# Out:
# (1000, 12)

# %%
flights.columns.tolist()
# Out:
# ['flight_id',
#  'origin',
#  'destination',
#  'departure_date',
#  'departure_time',
#  'base_fare_cad',
#  'capacity',
#  'seats_remaining',
#  'demand_score',
#  'demand_level',
#  'season',
#  'is_weekend']

# %%
flights.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   flight_id        1000 non-null   str
#  1   origin           1000 non-null   str
#  2   destination      1000 non-null   str
#  3   departure_date   1000 non-null   str
#  4   departure_time   1000 non-null   str
#  5   base_fare_cad    1000 non-null   float64
#  6   capacity         1000 non-null   int64
#  7   seats_remaining  1000 non-null   int64
#  8   demand_score     1000 non-null   float64
#  9   demand_level     1000 non-null   str
#  10  season           1000 non-null   str
#  11  is_weekend       1000 non-null   bool
# dtypes: bool(1), float64(2), int64(2), str(7)
# memory usage: 87.0 KB

# %%
from flight import Flight

# %%
row = flights.iloc[0]

# %%
flight1 = Flight(
    flight_id=row["flight_id"],
    origin=row["origin"],
    destination=row["destination"],
    departure_date=row["departure_date"],
    departure_time=row["departure_time"],
    base_fare_cad=row["base_fare_cad"],
    capacity=row["capacity"],
    seats_remaining=row["seats_remaining"],
    demand_score=row["demand_score"],
    demand_level=row["demand_level"],
    season=row["season"],
    is_weekend=row["is_weekend"]
)

# %%
flight1

# %%
flight1.flight_id
# Out:
# 'PA0001'

# %%
flight1.occupancy_rate()
# Out:
# 100.0

# %%
flight1.days_to_departure()
# Out:
# 4

# %%
flight1.to_dict()
# Out:
# {'flight_id': 'PA0001',
#  'origin': 'YUL',
#  'destination': 'YYZ',
#  'departure_date': '2026-09-24',
#  'departure_time': '18:35',
#  'base_fare_cad': 110.46,
#  'capacity': 180,
#  'seats_remaining': 0,
#  'demand_score': 1.32,
#  'demand_level': 'high',
#  'season': 'regular',
#  'is_weekend': False}

# %%
# !python -m pytest test_flight.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.14.7, pytest-9.1.1, pluggy-1.6.0 -- c:\Users\NATHAN-PC\AppData\Local\Python\pythoncore-3.14-64\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\NATHAN-PC\Potter-Airline-Project
# collecting ... collected 6 items
#
# test_flight.py::test_occupancy_rate PASSED                               [ 16%]
# test_flight.py::test_full_occupancy PASSED                               [ 33%]
# test_flight.py::test_days_to_departure PASSED                            [ 50%]
# test_flight.py::test_departure_today PASSED                              [ 66%]
# test_flight.py::test_to_dict_flight_id PASSED                            [ 83%]
# test_flight.py::test_to_dict_capacity PASSED                             [100%]
#
# ============================== 6 passed in 0.02s ==============================

# %%
flights["departure_date"] = pd.to_datetime(flights["departure_date"])

print(flights["departure_date"].min())
print(flights["departure_date"].max())
# Out:
# 2026-09-18 00:00:00
# 2027-03-16 00:00:00

# %%
sorted(
    set(flights["origin"]) |
    set(flights["destination"])
)
# Out:
# ['YEG', 'YHZ', 'YOW', 'YUL', 'YVR', 'YWG', 'YYC', 'YYZ']

# %% [markdown]
# # SQL CRUD TEST

# %%
# !python -m pytest test_sql_crud.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.14.7, pytest-9.1.1, pluggy-1.6.0 -- c:\Users\NATHAN-PC\AppData\Local\Python\pythoncore-3.14-64\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\NATHAN-PC\Potter-Airline-Project
# collecting ... collected 4 items
#
# test_sql_crud.py::test_create_database_and_select_data PASSED            [ 25%]
# test_sql_crud.py::test_load_data PASSED                                  [ 50%]
# test_sql_crud.py::test_update_base_fare PASSED                           [ 75%]
# test_sql_crud.py::test_delete_flight PASSED                              [100%]
#
# ============================== 4 passed in 0.94s ==============================
