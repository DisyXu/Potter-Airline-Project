# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('potter_airlines_flights.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of     flight_id origin destination departure_date departure_time  base_fare_cad  \
# 0      PA0001    YUL         YYZ     2026-09-24          18:35         110.46
# 1      PA0002    YWG         YYZ     2026-10-10          16:10         146.71
# 2      PA0003    YHZ         YUL     2026-09-24          16:10         132.83
# 3      PA0004    YYC         YEG     2027-02-15          10:45          93.53
# 4      PA0005    YYZ         YHZ     2026-10-27          08:15         165.21
# ..        ...    ...         ...            ...            ...            ...
# 995    PA0996    YHZ         YUL     2027-01-29          21:05         141.60
# 996    PA0997    YUL         YYZ     2026-11-13          08:15         113.04
# 997    PA0998    YYZ         YUL     2027-01-04          18:35         126.18
# 998    PA0999    YVR         YYZ     2026-11-07          06:30         237.08
# 999    PA1000    YUL         YYZ     2026-11-21          06:30         110.32
#
# ...

# %%
df. describe().round(2)
# Out:
#        base_fare_cad  capacity  seats_remaining  demand_score
# count        1000.00   1000.00          1000.00       1000.00
# mean          149.72    167.00            83.27          1.10
# std            50.72     36.79            38.29          0.15
# min            85.83    120.00             0.00          0.72
# 25%           113.66    120.00            54.00          0.99
# 50%           132.05    150.00            80.00          1.10
# 75%           168.66    180.00           109.00          1.21
# max           285.98    220.00           202.00          1.45

# %%
for col in df.columns:
    print(f"=== {col} summary ===")
    print(df[col].value_counts(dropna=False))  # include missing values
    print("-" * 30)
# Out:
# === flight_id summary ===
# flight_id
# PA0001    1
# PA0672    1
# PA0659    1
# PA0660    1
# PA0661    1
#          ..
# PA0339    1
# PA0340    1
# PA0341    1
# PA0342    1
# PA1000    1
# Name: count, Length: 1000, dtype: int64
# ------------------------------
# === origin summary ===
# origin
# YYZ    305
# YVR    141
# YYC    140
# YUL    108
# YHZ    101
# YEG     87
# YWG     73
# YOW     45
# Name: count, dtype: int64
# ------------------------------
# === destination summary ===
# destination
# YYZ    303
# YYC    151
# YVR    130
# YUL    116
# YHZ    113
# YEG     95
# YOW     47
# YWG     45
# Name: count, dtype: int64
# ------------------------------
# === departure_date summary ===
# departure_date
# 2027-02-17    12
# 2027-02-19    11
# 2026-11-05    11
# 2027-02-12    10
# 2026-10-04    10
#               ..
# 2027-02-23     1
# 2026-10-16     1
# 2026-10-02     1
# 2027-02-27     1
# 2026-10-06     1
# Name: count, Length: 178, dtype: int64
# ...
